# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import glob
import numpy as np
import os
import pandas as pd
import pandas_profiling

# %%
# Suppress scientific notation and limit to 2 decimal places
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Get directory of air bnb files
abb_dir = os.listdir('gdrive/My Drive/airbnb')

# %%
 abb_dir
# Out:
# ['calendar_summary.csv',
#  'neighbourhoods.csv',
#  'listings.csv',
#  'listings_summary.csv',
#  'reviews.csv',
#  'reviews_summary.csv']

# %%
path_list = []
df_name_list = []
path =  'gdrive/My Drive/airbnb/' 

for file_name in abb_dir:
    # Generate path names and create path list
    path_name = path + file_name
    path_list.append(path_name)
    # Generate file names and create file list
    if file_name.endswith('.csv'):
      df_name_list.append(file_name[:-4])

# %%
path_list
# Out:
# ['gdrive/My Drive/airbnb/calendar_summary.csv',
#  'gdrive/My Drive/airbnb/neighbourhoods.csv',
#  'gdrive/My Drive/airbnb/listings.csv',
#  'gdrive/My Drive/airbnb/listings_summary.csv',
#  'gdrive/My Drive/airbnb/reviews.csv',
#  'gdrive/My Drive/airbnb/reviews_summary.csv']

# %%
df_name_list
# Out:
# ['calendar_summary',
#  'neighbourhoods',
#  'listings',
#  'listings_summary',
#  'reviews',
#  'reviews_summary']

# %% [markdown]
# https://i.stack.imgur.com/MFPhB.png
# possible resource

# %%
calendar_summary = pd.read_csv('gdrive/My Drive/airbnb/calendar_summary.csv')
neighbourhoods = pd.read_csv('gdrive/My Drive/airbnb/neighbourhoods.csv')
listings = pd.read_csv('gdrive/My Drive/airbnb/listings.csv')
listings_summary = pd.read_csv('gdrive/My Drive/airbnb/listings_summary.csv')
reviews = pd.read_csv('gdrive/My Drive/airbnb/reviews.csv')
reviews_summary = pd.read_csv('gdrive/My Drive/airbnb/reviews_summary.csv')

# %%
x = df_name_list[0]

# %%
x
# Out:
# 'calendar_summary'

# %%
x =x.replace(" ' ", " ")

# %%
locals()
# Out:
# {'In': ['',
#   "from google.colab import drive\ndrive.mount('/content/gdrive')",
#   'import glob\nimport numpy as np\nimport os\nimport pandas as pd\nimport pandas_profiling',
#   "pd.set_option('display.float_format', lambda x: '%.2f' % x)",
#   "abb_dir = os.listdir('gdrive/My Drive/airbnb')",
#   'abb_dir',
#   "path_list = []\ndf_name_list = []\npath =  'gdrive/My Drive/airbnb/' \n\nfor file_name in abb_dir:\n    # Generate path names and create path list\n    path_name = path + file_name\n    path_list.append(path_name)\n    # Generate file names and create file list\n    if file_name.endswith('.csv'):\n      df_name_list.append(file_name[:-4])",
#   'path_list',
#   'df_name_list',
# ...

# %%
y
# Out:
# 3

# %%
calendar_summary.head(5)
# Out:
#    listing_id        date available price
# 0        2015  2019-09-10         f   NaN
# 1        2015  2019-09-09         f   NaN
# 2        2015  2019-09-08         f   NaN
# 3        2015  2019-09-07         f   NaN
# 4        2015  2019-09-06         f   NaN

# %%
print(buffalo)
# Out:
# 2

# %%
# Generate list of names and read csv to pd DataFrames
path_list = []

for i in abb_dir:
    path_list.append(path + abb_dir)
    #if abb_dir[i].endswith('.csv'):
      #df_name_list.append(file_name[:-4])

#for d, f in zip(df_name_list, path_list):
  #print(d)
 # print(f) 
  #d = pd.read_csv('f')
  # print(d)
  #print(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-53c31dcea734> in <module>()
#       2
#       3 for i in abb_dir:
# ----> 4     path_list.append(path + abb_dir)
#       5     #if abb_dir[i].endswith('.csv'):
#       6       #df_name_list.append(file_name[:-4])
#
# TypeError: must be str, not list

# %%
 type(path_list[0])
# Out:
# str

# %%
def make_frame(nm, pl):
  for n, p in zip(nm, pl):
    print(n,p)

# %%
make_frame(df_name_list, path_list)
# Out:
# calendar_summary gdrive/My Drive/airbnb/calendar_summary.csv
# listings gdrive/My Drive/airbnb/listings.csv
# neighbourhoods gdrive/My Drive/airbnb/neighbourhoods.csv
# reviews gdrive/My Drive/airbnb/reviews.csv
# listings_summary gdrive/My Drive/airbnb/listings_summary.csv
# reviews_summary gdrive/My Drive/airbnb/reviews_summary.csv

# %%
reviews.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9e45c92d513a> in <module>()
# ----> 1 reviews.describe()
#
# NameError: name 'reviews' is not defined

# %%
# Out:
# [         listing_id        date available price
#  0              2015  2019-09-10         f   NaN
#  1              2015  2019-09-09         f   NaN
#  2              2015  2019-09-08         f   NaN
#  3              2015  2019-09-07         f   NaN
#  4              2015  2019-09-06         f   NaN
#  ...             ...         ...       ...   ...
#  8231475    29809357  2018-11-11         f   NaN
#  8231476    29809357  2018-11-10         f   NaN
#  8231477    29809357  2018-11-09         f   NaN
#  8231478    29809357  2018-11-08         f   NaN
#  8231479    29809357  2018-11-07         f   NaN
#
#  [8231480 rows x 4 columns],              id  ... availability_365
#  0          2015  ...              141
#  1          2695  ...                0
#  2          3176  ...              220
#  3          3309  ...              297
#  4          7071  ...               26
#  ...         ...  ...              ...
#  22547  29856708  ...              314
# ...

# %%
df2= pd.read_csv('gdrive/My Drive/airbnb/reviews.csv')

# %%
df2.head()
# Out:
#    listing_id        date
# 0        2015  2016-04-11
# 1        2015  2016-04-15
# 2        2015  2016-04-26
# 3        2015  2016-05-10
# 4        2015  2016-05-14

# %%
df = pd.read_csv("gdrive/My Drive/airbnb/calendar_summary.csv")

# %%
df.head()
# Out:
#    listing_id        date available price
# 0        2015  2019-09-10         f   NaN
# 1        2015  2019-09-09         f   NaN
# 2        2015  2019-09-08         f   NaN
# 3        2015  2019-09-07         f   NaN
# 4        2015  2019-09-06         f   NaN

# %%
df_list
# Out:
# [         listing_id        date available price
#  0              2015  2019-09-10         f   NaN
#  1              2015  2019-09-09         f   NaN
#  2              2015  2019-09-08         f   NaN
#  3              2015  2019-09-07         f   NaN
#  4              2015  2019-09-06         f   NaN
#  ...             ...         ...       ...   ...
#  8231475    29809357  2018-11-11         f   NaN
#  8231476    29809357  2018-11-10         f   NaN
#  8231477    29809357  2018-11-09         f   NaN
#  8231478    29809357  2018-11-08         f   NaN
#  8231479    29809357  2018-11-07         f   NaN
#
#  [8231480 rows x 4 columns],              id  ... availability_365
#  0          2015  ...              141
#  1          2695  ...                0
#  2          3176  ...              220
#  3          3309  ...              297
#  4          7071  ...               26
#  ...         ...  ...              ...
#  22547  29856708  ...              314
# ...

# %%
cols(reviews_summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-a62268b32cbe> in <module>()
# ----> 1 cols(reviews_summary)
#
# NameError: name 'reviews_summary' is not defined

# %%
def csv_df(df_name, df_file):
  for nm, fl, in df_name, df_file:
    print(nm)

# %%
for a, b in zip([file_list, df_name_list]):
  print(a, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-de48e7938181> in <module>()
# ----> 1 for a, b in zip([file_list, df_name_list]):
#       2   print(a, b)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for nm, fl in df_name

# %%
name_list
# Out:
# ['calendar_summary',
#  'listings',
#  'neighbourhoods',
#  'reviews',
#  'listings_summary',
#  'reviews_summary']

# %%
list_again = []
path = "gdrive/My Drive/airbnb"
for df_name in name_list, for filename in os.listdir('gdrive/My Drive/airbnb/'):
  #for filename in os.listdir('gdrive/My Drive/airbnb/'):
  df_name = str(filename)
  list_again.append(df_name)

#('gdrive/My Drive/airbnb/'):
  #get_it = path.join(name)
  #for dfn in name_list:
    #dfn = pd.read(csv('name'))
# Out:
#   File "<ipython-input-35-ed58ba9d91ac>", line 3
#     for df_name in name_list, for filename in os.listdir('gdrive/My Drive/airbnb/'):
#                                 ^
# SyntaxError: invalid syntax

# %%
for num, cheese, color in zip([1,2,3], ['manchego', 'stilton', 'brie'], 
                              ['red', 'blue', 'green']):
    print('{} {} {}'.format(num, color, cheese))
# Out:
# 1 red manchego
# 2 blue stilton
# 3 green brie

# %%
list_again
# Out:
# ['calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv',
#  'calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv',
#  'calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv',
#  'calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv',
#  'calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv',
#  'calendar_summary.csv',
#  'listings.csv',
#  'neighbourhoods.csv',
#  'reviews.csv',
#  'listings_summary.csv',
#  'reviews_summary.csv']

# %%
calendar_sum=pd.read_csv('gdrive/My Drive/airbnb/calendar_summary.csv')

# %%
 names = []
path = "gdrive/My Drive/airbnb"                     # dir path
all_files = glob.glob(os.path.join(path, "*.csv")) #make list of paths

for file in all_files:
    file_name = file.split('\\')[-1].split('.')[0] # create string for df name
    dfn = pd.read_csv(file,skiprows=5)
    names.append(str(dfn))

# %%
names
# Out:
# ['             2015  2019-09-06  f Unnamed: 3\n0            2015  2019-09-05  f        NaN\n1            2015  2019-09-04  f        NaN\n2            2015  2019-09-03  f        NaN\n3            2015  2019-09-02  f        NaN\n4            2015  2019-09-01  f        NaN\n...           ...         ... ..        ...\n8231470  29809357  2018-11-11  f        NaN\n8231471  29809357  2018-11-10  f        NaN\n8231472  29809357  2018-11-09  f        NaN\n8231473  29809357  2018-11-08  f        NaN\n8231474  29809357  2018-11-07  f        NaN\n\n[8231475 rows x 4 columns]',
# ...

# %%
def get_files(dir):
  """function to read in files and remove csv"""
  for file in os.listdir('gdrive/My Drive/airbnb'):
    print(file)
  #airbnbfile = pd.read_csv(airbnbfile)

# %%
def getfiles('gdrive/My Drive/airbnb')
# Out:
#   File "<ipython-input-127-cde3797c149b>", line 1
#     def getfiles('gdrive/My Drive/airbnb')
#                                         ^
# SyntaxError: invalid syntax

# %%
calendar_sum=pd.read_csv('gdrive/My Drive/airbnb/calendar_summary.csv')

# %%
'filename.csv' = 'filename'.str.rstrip('.csv')
# Out:
#   File "<ipython-input-124-f14804f7e51e>", line 1
#     'filename.csv' = 'filename'.str.rstrip('.csv')
#                                                   ^
# SyntaxError: can't assign to literal

# %%
print(calendar_sum.columns.tolist())
calendar_sum.describe()
# """
# Notes on comparing with listings_sum
# 1) 'listing_id' not included in listing_sum, not equivalent to 'id'
# 2) 'date' not included in listing_sum
# 3) 'available' not equivalent to and availability--30, 365, 60, 90
# 4) 8231480 entries vs. 22552 in listings_sum
# """
# Out:
# ['listing_id', 'date', 'available', 'price']
#        listing_id
# count  8231480.00
# mean  15715604.77
# std    8551879.55
# min       2015.00
# 25%    8065953.50
# 50%   16866381.00
# 75%   22583930.75
# max   29867352.00

# %%
pd_and_sum(abb_dir)
# Out:
# calendar_summary.csv
# listings.csv
# neighbourhoods.csv
# reviews.csv
# listings_summary.csv
# reviews_summary.csv

# %%
from pandas.util.testing import assert_frame_equal, assert_series_equal

# %%
assert_series_equal(calendar_sum['price'], listings_sum['price'])

# %%
calendar_sum.describe()
#same count as previous: 8231480
# Out:
#        listing_id
# count  8231480.00
# mean  15715604.77
# std    8551879.55
# min       2015.00
# 25%    8065953.50
# 50%   16866381.00
# 75%   22583930.75
# max   29867352.00

# %%
listings=pd.read_csv('gdrive/My Drive/airbnb/listings.csv')

# %%
print(listings.columns.tolist())
listings.describe()
# id, equivalent
# host_id, equivalent
##################
#NOT equivalent
# name not equivalent
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#                id  ...  availability_365
# count    22552.00  ...          22552.00
# mean  15715604.77  ...             79.85
# std    8552068.64  ...            119.37
# min       2015.00  ...              0.00
# 25%    8065953.50  ...              0.00
# 50%   16866381.00  ...              4.00
# 75%   22583930.75  ...            129.00
# max   29867352.00  ...            365.00
#
# [8 rows x 10 columns]

# %%
assert_series_equal(listings['neighbourhood_group'], listings_sum['neighbourhood_group_cleansed'])

# %%
nhood=pd.read_csv('gdrive/My Drive/airbnb/neighbourhoods.csv')

# %%
nhood.describe()
# Out:
#        neighbourhood_group         neighbourhood
# count                  138                   138
# unique                  12                   138
# top     Treptow - Köpenick  Prenzlauer Berg Nord
# freq                    20                     1

# %%
reviews=pd.read_csv('gdrive/My Drive/airbnb/reviews.csv')

# %%
reviews.describe()
# Out:
#        listing_id
# count   401963.00
# mean  10273819.76
# std    8097067.83
# min       2015.00
# 25%    2421223.00
# 50%    9085319.00
# 75%   17106359.00
# max   29849565.00

# %%
reviews_sum=pd.read_csv('gdrive/My Drive/airbnb/reviews_summary.csv')

# %%
listings_sum=pd.read_csv('gdrive/My Drive/airbnb/listings_summary.csv')

# %%
listings_sum.describe()
# Out:
#                id  ...  reviews_per_month
# count    22552.00  ...           18638.00
# mean  15715604.77  ...               1.14
# std    8552068.64  ...               1.51
# min       2015.00  ...               0.01
# 25%    8065953.50  ...               0.18
# 50%   16866381.00  ...               0.54
# 75%   22583930.75  ...               1.50
# max   29867352.00  ...              36.67
#
# [8 rows x 34 columns]

# %%
listings_sum.columns.tolist()
# Produce list of all other data files, and test to see if they are subsets of listings_sum
#loading above
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
# Use pandas profiling
pandas_profiling.ProfileReport(listings_sum)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...
